# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
with open('shellpath_chull_vs_sphere.json') as f:
    data = json.load(f)
    
df = pd.json_normalize(data)

# %%
df
# Out:
#     final_path_length  goals_visited  napples      planner_name    run_time  \
# 0          256.864022             50       50  ShellPathPlanner   11.758564
# 1          202.802277             49       50  ShellPathPlanner   53.285542
# 2          458.446898            150      150  ShellPathPlanner  245.206790
# 3          476.458614            150      150  ShellPathPlanner  229.933861
# 4          420.270895            147      150  ShellPathPlanner  216.998399
# 5          655.672362            148      150  ShellPathPlanner   24.682183
# 6          700.743937            148      150  ShellPathPlanner   22.510504
# 7          191.494374             50       50  ShellPathPlanner   50.970148
# 8          714.782804            146      150  ShellPathPlanner   24.770604
# 9          696.370997            147      150  ShellPathPlanner   21.894515
# 10         250.418951             48       50  ShellPathPlanner    9.227994
# ...
